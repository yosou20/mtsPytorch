# %%
# utils for data manupulation
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import time
import itertools
import seaborn as sns
# %matplotlib inline

# %%
# utils for data visualization
import cufflinks as cf
import plotly.graph_objs as go
import plotly.offline as py
import plotly.express as px
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected= True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.11.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.11.1.min']
#             }
#         });
# ...

# %%
#%pip install torchmetrics

# %%
# utils for mtrics computation
from torchmetrics import  F1Score

f1 = F1Score(num_classes=3)
#>>> f1(preds, target)
#f1 = f1Score()
f1
# Out:
# F1Score()

# %%
#test_df.head()

# %%
rc_data = np.load('../data/matrix_data/reconstructed_data/reconstructed_data_810.npy', mmap_mode='r')
x=len(rc_data[1][0])
print(x)
rc_df = pd.DataFrame(rc_data[0][0])
df_list = []
for i in range(0,3):
    df_i = pd.DataFrame(rc_data[4][i])
    df_list.append(df_i)

#rc_data.iloc[:,[0]].plot()
# Out:
# 30

# %%
rc_df = pd.DataFrame(rc_data[0][0])
rc_self_matrix= pd.DataFrame(rc_data[-1][0])
rc_self_matrix
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.119302  0.230495  0.105705  0.103482  0.091852  0.233251  0.082680
# 1   0.232535  0.501341  0.197626  0.202987  0.182543  0.491676  0.186210
# 2   0.104360  0.202810  0.084412  0.085400  0.069269  0.207129  0.063677
# 3   0.109264  0.202695  0.089162  0.106039  0.079650  0.215156  0.070625
# 4   0.089842  0.180022  0.072249  0.076973  0.066081  0.185231  0.058208
# 5   0.245663  0.496713  0.216446  0.211670  0.194497  0.499215  0.190246
# 6   0.089564  0.187391  0.065486  0.069974  0.060523  0.183759  0.059427
# 7   0.103632  0.218938  0.098979  0.095465  0.080102  0.215920  0.080620
# 8   0.152900  0.338309  0.160086  0.158094  0.136565  0.342668  0.142011
# 9   0.173145  0.358882  0.163895  0.159457  0.140763  0.355648  0.150721
# 10  0.117276  0.223876  0.094052  0.089822  0.077657  0.211497  0.075929
# 11  0.235851  0.490581  0.203416  0.217998  0.197124  0.497937  0.203505
# ...

# %%
origin_data = np.load('../data/matrix_data/test_data/test_data_810.npy', mmap_mode='r')

origin_data_list = []
for i in range(0,3):
    df_i = pd.DataFrame(origin_data[4][i])
    origin_data_list.append(df_i)
#tt=len(origin_data[4][2])
#print(tt)
origin_df = pd.DataFrame(origin_data[4][0])
#origin_data.iloc[:,[0]].plot()
#origin_data

# %%
cf_matrix = confusion_matrix(y_true, y_pred)
df_cm = pd.DataFrame(cf_matrix/np.sum(cf_matrix) *10, index = [i for i in classes],
                     columns = [i for i in classes])
plt.figure(figsize = (12,7))
sn.heatmap(df_cm, annot=True)
plt.savefig('output.png')

# %%
# plt.figure()
# plt.plot(origin_data.iloc[:, [19]],label ='original')
# plt.plot(rc_data.iloc[:,[19]], label = "reconstructed")
# #plt.legend()
# plt.show()

# %%
fig, ax = plt.subplots(1,3, figsize=(16,4))
ax[0].plot(origin_data_list[0].iloc[:, [19]], label = 'Origin data')
ax[0].plot(df_list[0].iloc[:, [19]], label = 'reconst win_10')
ax[0].legend(ncol = 2, loc = 2)
#ax[0].legend()
ax[1].plot(origin_data_list[1].iloc[:, [19]])
ax[1].plot(df_list[1].iloc[:, [19]])
ax[2].plot(origin_data_list[2].iloc[:, [19]])
ax[2].plot(df_list[2].iloc[:, [19]])
plt.show()

# %% [markdown]
# ## List of window size and step size = 5

# %%
fig, ax = plt.subplots(1,3, figsize=(16,4))
ax[0].plot(origin_df.iloc[:, [19]], label = 'Origin data')
ax[0].plot(df_list[0].iloc[:, [19]], label = 'reconst. win 10')
ax[0].legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
       ncol=2, mode="expand", borderaxespad=0.)

#ax[0].legend()
ax[1].plot(origin_df.iloc[:, [19]], label ='Origin data')
ax[1].plot(df_list[1].iloc[:, [19]], label = 'reconst. win 30')
ax[1].legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
       ncol=2, mode="expand", borderaxespad=0.)

ax[2].plot(origin_df.iloc[:, [19]], label ='Origin data')
ax[2].plot(df_list[2].iloc[:, [19]],label = 'reconst. win 60')
ax[2].legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
       ncol=2, mode="expand", borderaxespad=0.)
plt.show()

# %% [markdown]
# ## step size 2

# %%
origin_df = pd.DataFrame(origin_data[0][0])

fig, ax = plt.subplots(1,3, figsize=(16,4))
ax[0].plot(origin_df.iloc[:, [19]], label = 'Origin data')
ax[0].plot(df_list[0].iloc[:, [19]], label = 'reconst. win 10')
ax[0].legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
       ncol=2, mode="expand", borderaxespad=0.)

#ax[0].legend()
ax[1].plot(origin_df.iloc[:, [19]], label ='Origin data')
ax[1].plot(df_list[1].iloc[:, [19]], label = 'reconst. win 30')
ax[1].legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
       ncol=2, mode="expand", borderaxespad=0.)

ax[2].plot(origin_df.iloc[:, [19]], label ='Origin data')
ax[2].plot(df_list[2].iloc[:, [19]],label = 'reconst. win 60')
ax[2].legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
       ncol=2, mode="expand", borderaxespad=0.)
plt.show()

# %%
plt.figure()
plt.plot(origin_df.iloc[:, [19]], label = 'Origin data')
plt.plot(df_list[2].iloc[:, [19]], label = 'reconst. win 60')
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
       ncol=2, mode="expand", borderaxespad=0.)

plt.show()

# %%
fig, ax = plt.subplots(1,3, figsize=(16,4))
ax[0].imshow(rc_df.iloc[0:,])
ax[1].imshow(rc_df.iloc[1:,])
ax[2].imshow(rc_df.iloc[2:,])
plt.show()
#plt.legend()

# %%
fig, ax = plt.subplots(figsize=(16,4))
shw = ax.imshow(rc_df.iloc[0:,])
bar = plt.colorbar(shw)
plt.xlabel('Features')
plt.ylabel('Features')
#bar.set_label('ColorBar')
plt.show()

# %%
origin_train_data = np.load('./matrix_data/train_data/train_data_100.npy')
data_w10 = np.load('./matrix_data/matrix_win_10.npy')
origin_train_data_df = pd.DataFrame(origin_train_data[0][0]).corr()

fig, ax = plt.subplots(figsize=(16,4))
shw = ax.imshow(origin_train_data_df.iloc[0:,])
#shw =shw.corr()
bar = plt.colorbar(shw)
plt.xlabel('Features')
plt.ylabel('Features')
#bar.set_label('ColorBar')
plt.show()

# %%
data_w10 = np.load('./matrix_data/matrix_win_10.npy')
data_w10_df = pd.DataFrame(data_w10[6])
data_w10_df
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.145589  0.138024  0.152647  0.271631  0.270509  0.138994  0.249844
# 1   0.138024  0.153898  0.147224  0.261022  0.261003  0.131027  0.239048
# 2   0.152647  0.147224  0.176809  0.301142  0.296084  0.149196  0.271279
# 3   0.271631  0.261022  0.301142  0.529613  0.521777  0.261241  0.481607
# 4   0.270509  0.261003  0.296084  0.521777  0.519324  0.259388  0.477413
# 5   0.138994  0.131027  0.149196  0.261241  0.259388  0.138314  0.238166
# 6   0.249844  0.239048  0.271279  0.481607  0.477413  0.238166  0.446407
# 7   0.252498  0.244801  0.277735  0.488789  0.482800  0.242157  0.448975
# 8   0.280986  0.274590  0.307704  0.542549  0.538747  0.268231  0.497223
# 9   0.265153  0.246686  0.290048  0.508806  0.506082  0.254776  0.466746
# 10  0.168008  0.157122  0.178128  0.315331  0.314978  0.158779  0.287556
# 11  0.186376  0.180028  0.206953  0.361415  0.358178  0.180411  0.331306
# ...

# %%
#rc_data = pd.DataFrame(rc_data)
corr_data= rc_data.corr()
ax = sns.heatmap(corr_data)
#sns.set_theme()

# %%
# see all matrix

all_matrix_w10 =  np.load("../data/matrix_data/matrix_win_10.npy", mmap_mode='r')
tt=len(all_matrix_w10)
print(tt)
#all_matrix_w10 = pd.DataFrame(all_matrix_w10)
#print(all_matrix_w10)
# Out:
# 2000

# %%
sensor_df = pd.read_csv('gas_mixiture_data.csv')
sensor_df.head()
# Out:
#    Time (s)  CO (ppm)  Humidity (%r.h.)  Temperature (C)  Flow rate (mL/min)  \
# 0     0.000       0.0             50.25            26.54            243.0538
# 1     0.309       0.0             50.25            26.54            242.0039
# 2     0.619       0.0             50.25            26.54            241.5810
# 3     0.928       0.0             50.25            26.54            241.1596
# 4     1.235       0.0             50.25            26.54            240.7642
#
#    Heater voltage (V)  R1 (MOhm)  R2 (MOhm)  R3 (MOhm)  R4 (MOhm)  R5 (MOhm)  \
# 0              0.8805     0.0643     0.1489     0.1056     0.1051     0.1093
# 1              0.8928     0.0710     0.1436     0.1059     0.1013     0.1081
# 2              0.8960     0.0762     0.1402     0.1080     0.1007     0.1100
# 3              0.8980     0.0797     0.1392     0.1112     0.1011     0.1121
# 4              0.8983     0.0822     0.1395     0.1142     0.1021     0.1143
#
# ...

# %%
rc_data1 = np.load('../data/matrix_data/reconstructed_data/reconstructed_data_1000.npy', mmap_mode='r')
x=len(rc_data1[0][0])
print(x)
rc_data = pd.DataFrame(rc_data1[0][0])
#rc_data.iloc[:,[0]].plot()
rc_data
# Out:
# 30
#           0         1         2         3         4         5         6   \
# 0   0.431491  0.288141  0.456138  0.187126  0.437971  0.277917  0.227399
# 1   0.274586  0.215618  0.302669  0.130604  0.297898  0.199427  0.147119
# 2   0.439626  0.302114  0.486807  0.195898  0.472385  0.293431  0.255736
# 3   0.186271  0.128537  0.205018  0.092966  0.205844  0.130496  0.101873
# 4   0.441372  0.299385  0.481491  0.205481  0.484260  0.299933  0.240051
# 5   0.284111  0.198871  0.298426  0.142087  0.301254  0.204291  0.153059
# 6   0.217093  0.143851  0.248004  0.101014  0.239092  0.146815  0.121888
# 7   0.185277  0.114632  0.191999  0.070817  0.197492  0.119821  0.094837
# 8   0.239108  0.154119  0.245861  0.104474  0.261042  0.161398  0.125467
# 9   0.395104  0.256228  0.415725  0.169675  0.415209  0.262219  0.196236
# 10  0.451141  0.301548  0.494341  0.197503  0.495244  0.313986  0.244886
# 11  0.291904  0.196390  0.307753  0.117981  0.300708  0.183560  0.133185
# ...

# %%
origin_data1 = np.load('../data/matrix_data/test_data/test_data_1000.npy', mmap_mode='r')
tt=len(origin_data1[0][0])
print(tt)
origin_data = pd.DataFrame(origin_data1[0][0])
#origin_data.iloc[:,[0]].plot()
origin_data
# Out:
# 30
#           0         1         2         3         4         5         6   \
# 0   0.388395  0.215342  0.416209  0.170246  0.444209  0.215825  0.221863
# 1   0.215342  0.129401  0.241640  0.098664  0.252288  0.121092  0.128160
# 2   0.416209  0.241640  0.470497  0.188342  0.488558  0.233813  0.246005
# 3   0.170246  0.098664  0.188342  0.078343  0.199490  0.095489  0.100211
# 4   0.444209  0.252288  0.488558  0.199490  0.521666  0.249690  0.256830
# 5   0.215825  0.121092  0.233813  0.095489  0.249690  0.123131  0.122568
# 6   0.221863  0.128160  0.246005  0.100211  0.256830  0.122568  0.132491
# 7   0.183705  0.104848  0.198857  0.081927  0.214258  0.104194  0.104565
# 8   0.171285  0.095077  0.188978  0.074763  0.198775  0.093174  0.099063
# 9   0.425087  0.238634  0.463473  0.190040  0.492481  0.238653  0.245081
# 10  0.462050  0.261387  0.504288  0.205694  0.534482  0.259897  0.267169
# 11  0.315729  0.180688  0.344516  0.139985  0.364328  0.175196  0.182858
# ...

# %%
#f1(origin_data, rc_d)
# calculates recall for 1:100 dataset with 90 tp and 10 fn
from sklearn.metrics import recall_score
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

# %%
y_true =origin_data
y_pred =rc_data
#cf_matrix = confusion_matrix(y_true, y_pred)
#df_cm = pd.DataFrame(cf_matrix/np.sum(cf_matrix) *10, index = [i for i in 30],
#                     columns = [i for i in 30])
#plt.figure(figsize = (12,7))
#sn.heatmap(df_cm, annot=True)
#plt.savefig('output.png')

# %%
pred = y_true -y_pred
pred_df = pd.DataFrame(pred[0][0])
pred_df
pred_df.describe()
# Out:
#               0          1          2          3          4          5   \
# count  30.000000  30.000000  30.000000  30.000000  30.000000  30.000000
# mean    0.013111  -0.025482   0.025721   0.035533   0.031088  -0.007322
# std     0.032434   0.053137   0.028629   0.039871   0.038171   0.057291
# min    -0.039681  -0.113444  -0.015439  -0.022158  -0.025308  -0.098380
# 25%    -0.017483  -0.075293  -0.003426  -0.004273  -0.009971  -0.057967
# 50%     0.016736  -0.025154   0.030991   0.042555   0.041595  -0.002761
# 75%     0.043839   0.026122   0.053190   0.069981   0.059407   0.050082
# max     0.060049   0.050587   0.073072   0.100215   0.096583   0.068129
#
#               6          7          8          9   ...         20         21  \
# count  30.000000  30.000000  30.000000  30.000000  ...  30.000000  30.000000
# mean    0.035733   0.018995  -0.035404  -0.036765  ...  -0.046518  -0.051750
# std     0.035458   0.032518   0.026785   0.025043  ...   0.034032   0.038123
# ...

# %%
origin_data_last = pd.DataFrame(origin_data1[0][0])
rc_data_last = pd.DataFrame(rc_data1[-1][0])
residual =np.square(origin_data_last - rc_data_last)
residual
residual= [1 if i >0.005 else 0 for i in residual]
count_cum = 0
precision_score2 = 0.0
for p in residual:
    if p ==1:
        count_cum += 1

precision_score2 = count_cum/len(residual)
print(precision_score2)
print(count_cum)
print(len(residual))
# Out:
# 0.9666666666666667
# 29
# 30

# %%
from sklearn.metrics import precision_score
#y_true = origin_data_last.iloc[:,[-1]]
#y_pred = residual # rc_data_last.iloc[:,[-1]]
#precision_score(y_true, y_pred, average=None)
#y_true

# %%
epochs = [1, 2, 3, 4, 5]
loss = [0.006228, 0.002294,0.002187, 0.002133,0.002081]
plt.plot(epochs, loss)
