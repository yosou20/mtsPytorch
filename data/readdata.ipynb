# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#test_df.head()

# %%
rc_data = np.load('../data/matrix_data/reconstructed_data/reconstructed_data_810.npy', mmap_mode='r')
x=len(rc_data[0][0])
print(x)
rc_data = pd.DataFrame(rc_data[0][0])
#rc_data.iloc[:,[0]].plot()
rc_data
# Out:
# 30
#           0         1         2         3         4         5         6   \
# 0   0.137347  0.272455  0.100852  0.117625  0.108157  0.273980  0.120363
# 1   0.269335  0.593291  0.213669  0.249931  0.239643  0.589437  0.247724
# 2   0.097986  0.214275  0.079923  0.085602  0.089759  0.213292  0.089805
# 3   0.115938  0.249970  0.092445  0.108522  0.098644  0.248573  0.103839
# 4   0.110781  0.248181  0.092782  0.101960  0.109122  0.243680  0.100247
# 5   0.261903  0.583269  0.206549  0.247842  0.236215  0.587553  0.240259
# 6   0.108660  0.240129  0.086773  0.096429  0.096299  0.239655  0.098987
# 7   0.110272  0.225502  0.085184  0.097164  0.091890  0.222840  0.094830
# 8   0.116125  0.251802  0.088414  0.102084  0.096564  0.252906  0.101538
# 9   0.119969  0.275094  0.096419  0.110183  0.106434  0.276389  0.111761
# 10  0.093121  0.195630  0.071837  0.082695  0.080289  0.193872  0.080424
# 11  0.236294  0.518516  0.184415  0.224365  0.209887  0.514704  0.210023
# ...

# %%
origin_data = np.load('../data/matrix_data/test_data/test_data_810.npy', mmap_mode='r')
tt=len(origin_data[0][0])
print(tt)
origin_data = pd.DataFrame(origin_data[0][0])
#origin_data.iloc[:,[0]].plot()
origin_data
# Out:
# 30
#           0         1         2         3         4         5         6   \
# 0   0.207398  0.307055  0.154404  0.217489  0.208322  0.324950  0.197505
# 1   0.307055  0.462553  0.235779  0.324635  0.312599  0.487907  0.293983
# 2   0.154404  0.235779  0.126538  0.166734  0.160735  0.252365  0.149256
# 3   0.217489  0.324635  0.166734  0.235265  0.222634  0.348650  0.209922
# 4   0.208322  0.312599  0.160735  0.222634  0.219551  0.335762  0.200601
# 5   0.324950  0.487907  0.252365  0.348650  0.335762  0.525548  0.312502
# 6   0.197505  0.293983  0.149256  0.209922  0.200601  0.312502  0.192146
# 7   0.166437  0.249090  0.127169  0.180136  0.171478  0.264961  0.161034
# 8   0.108439  0.164603  0.084696  0.117188  0.114284  0.174561  0.104172
# 9   0.115808  0.169052  0.088125  0.124506  0.119171  0.185465  0.112778
# 10  0.141963  0.212709  0.109615  0.156120  0.147908  0.233607  0.137516
# 11  0.253648  0.375857  0.192490  0.269815  0.262077  0.404287  0.241008
# ...

# %%
plt.figure()
plt.plot(origin_data.iloc[:, [1]],label ='original')

plt.plot(rc_data.iloc[:,[1]], label = "reconstructed")
plt.legend()
plt.show()

# %%
#rc_data = pd.DataFrame(rc_data)
corr_data= rc_data.corr()
ax = sns.heatmap(corr_data)
sns.set_theme()

# %%
rc_data = pd.DataFrame(rc_data)
corr_data= rc_data.corr()
ax = sns.heatmap(corr_data, center=0, annot= False)
sns.set_theme()

# %%
# see all matrix

all_matrix_w10 =  np.load("../data/matrix_data/matrix_win_10.npy", mmap_mode='r')
tt=len(all_matrix_w10)
print(tt)
#all_matrix_w10 = pd.DataFrame(all_matrix_w10)
#print(all_matrix_w10)
# Out:
# 2000

# %%
sensor_df = pd.read_csv('gas_mixiture_data.csv')
sensor_df.head()
# Out:
#    Time (s)  CO (ppm)  Humidity (%r.h.)  Temperature (C)  Flow rate (mL/min)  \
# 0     0.000       0.0             50.25            26.54            243.0538
# 1     0.309       0.0             50.25            26.54            242.0039
# 2     0.619       0.0             50.25            26.54            241.5810
# 3     0.928       0.0             50.25            26.54            241.1596
# 4     1.235       0.0             50.25            26.54            240.7642
#
#    Heater voltage (V)  R1 (MOhm)  R2 (MOhm)  R3 (MOhm)  R4 (MOhm)  R5 (MOhm)  \
# 0              0.8805     0.0643     0.1489     0.1056     0.1051     0.1093
# 1              0.8928     0.0710     0.1436     0.1059     0.1013     0.1081
# 2              0.8960     0.0762     0.1402     0.1080     0.1007     0.1100
# 3              0.8980     0.0797     0.1392     0.1112     0.1011     0.1121
# 4              0.8983     0.0822     0.1395     0.1142     0.1021     0.1143
#
# ...

# %%
rc_data = np.load('../data/matrix_data/reconstructed_data/reconstructed_data_1000.npy', mmap_mode='r')
x=len(rc_data[0][0])
print(x)
rc_data = pd.DataFrame(rc_data[0][0])
#rc_data.iloc[:,[0]].plot()
rc_data
# Out:
# 30
#           0         1         2         3         4         5         6   \
# 0   0.292184  0.232205  0.224389  0.356576  0.249848  0.186677  0.312332
# 1   0.228384  0.186945  0.173336  0.281691  0.195367  0.148817  0.249707
# 2   0.225378  0.169559  0.175268  0.270758  0.184233  0.135675  0.234922
# 3   0.353200  0.290837  0.276300  0.459722  0.308147  0.230052  0.394368
# 4   0.248805  0.195427  0.185700  0.311003  0.229470  0.158533  0.272404
# 5   0.183807  0.151759  0.139023  0.228007  0.156099  0.127057  0.201483
# 6   0.311072  0.248374  0.241196  0.392813  0.270772  0.198674  0.366053
# 7   0.136852  0.106490  0.098602  0.167105  0.111190  0.086362  0.131000
# 8   0.256080  0.205302  0.194066  0.324995  0.221327  0.172272  0.295611
# 9   0.317634  0.261093  0.244676  0.402870  0.273775  0.209160  0.350718
# 10  0.262874  0.203179  0.199281  0.324604  0.226286  0.165222  0.287473
# 11  0.311232  0.256789  0.241991  0.402912  0.271772  0.206916  0.346668
# ...

# %%
origin_data = np.load('../data/matrix_data/test_data/test_data_1000.npy', mmap_mode='r')
tt=len(origin_data[0][0])
print(tt)
origin_data = pd.DataFrame(origin_data[0][0])
#origin_data.iloc[:,[0]].plot()
origin_data
# Out:
# 30
#           0         1         2         3         4         5         6   \
# 0   0.261611  0.223472  0.206594  0.339363  0.254755  0.188003  0.295454
# 1   0.223472  0.198895  0.186264  0.303402  0.223928  0.164154  0.273579
# 2   0.206594  0.186264  0.182422  0.284971  0.213920  0.152193  0.260800
# 3   0.339363  0.303402  0.284971  0.466807  0.338612  0.249560  0.423235
# 4   0.254755  0.223928  0.213920  0.338612  0.261772  0.185702  0.299213
# 5   0.188003  0.164154  0.152193  0.249560  0.185702  0.137227  0.220809
# 6   0.295454  0.273579  0.260800  0.423235  0.299213  0.220809  0.400369
# 7   0.126733  0.110914  0.104108  0.167994  0.126812  0.092410  0.148226
# 8   0.245771  0.228679  0.216827  0.355232  0.245575  0.183853  0.339623
# 9   0.318830  0.287228  0.275671  0.442059  0.323754  0.235273  0.403431
# 10  0.248489  0.215668  0.201471  0.325688  0.249212  0.179892  0.285536
# 11  0.293463  0.256956  0.240089  0.389012  0.293015  0.213601  0.345736
# ...
